# %% [markdown]
# ## Taking refrence from https://medium.com/analytics-vidhya/the-mastery-of-pandas-ii-bc4cf58c04f5

# %%
import pandas as pd

# %% [markdown]
# ## Dataframe merge, concatenation and Groupby

# %%
# In Pandas we merge with the merge method, which works pretty much like an SQL join with different tables

# %%
# NOTE: Use merge, which is an inner join by default:
# join, which is a left join by default:
# concat, which is an outer join by default:

# %%
df = pd.read_csv("train.csv") # importing .csv file

# %%
df1 = df.head(3)

# %%
df2 = df.tail(3)

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df2
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dfc = pd.concat([df1 , df2], axis = 0)  # concat data if axis is 0 so data comes under it

# %%
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# ...

# %%
df3 = pd.concat([df1 , df2], axis = 1)  # it adds different rows

# %%
df3
# Out:
#      PassengerId  Survived Pclass  \
# 0            1.0       0.0    3.0
# 1            2.0       1.0    1.0
# 2            3.0       1.0    3.0
# 888          NaN       NaN    NaN
# 889          NaN       NaN    NaN
# 890          NaN       NaN    NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 888                                                NaN     NaN   NaN    NaN
# 889                                                NaN     NaN   NaN    NaN
# 890                                                NaN     NaN   NaN    NaN
#
#     Parch            Ticket     Fare  ... Pclass  \
# 0     0.0         A/5 21171   7.2500  ...    NaN
# 1     0.0          PC 17599  71.2833  ...    NaN
# ...

# %%
df1 = pd.DataFrame({'a':range(6),
                    'b':[5,3,6,9,2,4]}, index=list('abcdef'))

# %%
df2 = pd.DataFrame({'c':range(4),
                    'a':range(4),
                    'd':[10,20,30, 40]}, index=list('abhi'))

# %%
df1
# Out:
#    a  b
# a  0  5
# b  1  3
# c  2  6
# d  3  9
# e  4  2
# f  5  4

# %%
df2
# Out:
#    c  a   d
# a  0  0  10
# b  1  1  20
# h  2  2  30
# i  3  3  40

# %%
# firstly use merge 
df3 = pd.merge(df1 , df2)   #inner join by default

# %%
df3
# Out:
#    a  b  c   d
# 0  0  5  0  10
# 1  1  3  1  20
# 2  2  6  2  30
# 3  3  9  3  40

# %%
df3 = pd.merge(df1 , df2 ,how = "outer" , right_on="a" , left_on="a")  # right_on is the key for right df and same as left_on

# %%
df3
# Out:
#    a  b    c     d
# 0  0  5  0.0  10.0
# 1  1  3  1.0  20.0
# 2  2  6  2.0  30.0
# 3  3  9  3.0  40.0
# 4  4  2  NaN   NaN
# 5  5  4  NaN   NaN

# %%
df3 = pd.merge(df1 , df2 ,how = "left" , right_on="a" , left_on="a")

# %%
df3
# Out:
#    a  b    c     d
# 0  0  5  0.0  10.0
# 1  1  3  1.0  20.0
# 2  2  6  2.0  30.0
# 3  3  9  3.0  40.0
# 4  4  2  NaN   NaN
# 5  5  4  NaN   NaN

# %%
df3 = pd.merge(df1 , df2 ,how = "right" , right_on="a" , left_on="a") # it work like sql joins

# %%
df3
# Out:
#    a  b  c   d
# 0  0  5  0  10
# 1  1  3  1  20
# 2  2  6  2  30
# 3  3  9  3  40

# %%
df4 = df3.groupby("d")  # similar to sql

# %%
df4.c.mean()
# Out:
# d
# 10    0.0
# 20    1.0
# 30    2.0
# 40    3.0
# Name: c, dtype: float64

# %% [markdown]
# ## Apply, Map, and Applymap

# %%
# Imagine you want to pass all the data belonging to one column through an specific function that transforms it in some way.

# %%
# map: It is very useful for example when we want to convert a categorical value to a boolean one

# %%
df3["pass"] = df3["d"].map(lambda marks : "Yes" if marks >= 33 else "No")

# %%
df3
# Out:
#    a  b  c   d pass
# 0  0  5  0  10   No
# 1  1  3  1  20   No
# 2  2  6  2  30   No
# 3  3  9  3  40  Yes

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# lets convert sex in boolean male for 1 and female for 0 this could have been done passing a dictionary as an argument, 
# where the keys represent the initial categories, and the values represent the new boolean levels

# %%
df["sex_bool"] = df["Sex"].map({"male":1 , "female":0})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# s.apply(func, convert_dtype=True, args=()) syntax

# %%
# lets convert Fare value doller to euro using apply method

# %%
#define a function that converts dollars to euro
def dolar_to_euro(dollars, exchange_rate):
    euros = dollars*exchange_rate
    return euros

# %%
df["Fare_Euro"] = df["Fare"].apply(dolar_to_euro , exchange_rate = 0.9)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# check old or not

# %%
df["old_or_not"] = df["Age"].apply(lambda age : 1 if age > 40 else 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sex_bool  Fare_Euro  \
# ...

# %%
# to find women who is old

# %%
df["old_women"] = df.apply(lambda row : 1 if (row["sex_bool"] == 0 and row["old_or_not"] == 1)  else 0 , axis = 1)

# %%
df.head(12)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# we can create new dataframe where we have only data to old women

# %%
owdf = df[df["old_women"] == 1]

# %%
owdf
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 52            53         1       1
# 132          133         0       3
# 167          168         0       3
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 254          255         0       3
# 259          260         1       2
# 268          269         1       1
# 272          273         1       2
# 275          276         1       1
# 276          277         0       3
# 299          300         1       1
# 337          338         1       1
# 362          363         0       3
# 366          367         1       1
# 380          381         1       1
# 432          433         1       2
# 440          441         1       2
# 458          459         1       2
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# ...

# %%
# ApplyMap is used when we have to apply on every field of an dataframe
import numpy as np

# %%
#Creating this new dataframe
part_cols = ['Screw', 'Nut', 'Nail', 'Bearing']
duration_part_df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=part_cols)

# %%
duration_part_df
# Out:
#     Screw  Nut  Nail  Bearing
# 0      82    6    15       72
# 1      46   52    62       49
# 2      36   63    29       61
# 3      81   12    40       63
# 4      61   37     2       53
# ..    ...  ...   ...      ...
# 95     14   35    32       73
# 96     86   13    52       98
# 97     34   38    52       58
# 98     22   84    20       40
# 99     44   90    91       99
#
# [100 rows x 4 columns]

# %%
# these data is for an perticular hour so if we need to convert it to whole year so we do

# %%
duration_part_df = duration_part_df.applymap(lambda row : row * 24)

# %%
duration_part_df # converted to day
# Out:
#     Screw   Nut  Nail  Bearing
# 0    1968   144   360     1728
# 1    1104  1248  1488     1176
# 2     864  1512   696     1464
# 3    1944   288   960     1512
# 4    1464   888    48     1272
# ..    ...   ...   ...      ...
# 95    336   840   768     1752
# 96   2064   312  1248     2352
# 97    816   912  1248     1392
# 98    528  2016   480      960
# 99   1056  2160  2184     2376
#
# [100 rows x 4 columns]
