# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name" : ["ritesh", "manish" , "ashish" , "nitish"],
    "age" : [21 , 23 , 24 , 19]
}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name  age
# 0  ritesh   21
# 1  manish   23
# 2  ashish   24
# 3  nitish   19

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.name[1]
# Out:
# 'manish'

# %%
df.head(2)
# Out:
#      name  age
# 0  ritesh   21
# 1  manish   23

# %%
df.tail(3)
# Out:
#      name  age
# 1  manish   23
# 2  ashish   24
# 3  nitish   19

# %%
df.describe() # it get mathematical data
# Out:
#              age
# count   4.000000
# mean   21.750000
# std     2.217356
# min    19.000000
# 25%    20.500000
# 50%    22.000000
# 75%    23.250000
# max    24.000000

# %% [markdown]
# #  to take csv file

# %%
finance = pd.read_csv("CSV.csv")

# %%
finance
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
finance.discribe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11180/1788219366.py in <module>
# ----> 1 finance.discribe()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'discribe'

# %%
type(finance["Value"].describe())
# Out:
# pandas.core.series.Series

# %%
finance["Year"][0] = 10
# Out:
# C:\Users\Ritesh\AppData\Local\Temp/ipykernel_11180/3527107079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finance["Year"][0] = 10

# %%
finance.head(3)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0    10                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  733,258  ANZSIC06 divisions A-S (excluding classes K633...
# 1  660,630  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %% [markdown]
# # change index

# %%
finance.index = finance["Year"]

# %%
finance.head()
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 10      10                     Level 1                99999
# 2020  2020                     Level 1                99999
# 2020  2020                     Level 1                99999
# 2020  2020                     Level 1                99999
# 2020  2020                     Level 1                99999
#
#      Industry_name_NZSIOC               Units Variable_code  \
# Year
# 10         All industries  Dollars (millions)           H01
# 2020       All industries  Dollars (millions)           H04
# 2020       All industries  Dollars (millions)           H05
# 2020       All industries  Dollars (millions)           H07
# 2020       All industries  Dollars (millions)           H08
#
#                                         Variable_name      Variable_category  \
# Year
# 10                                       Total income  Financial performance
# ...

# %%
finance.dtypes  # to checking the datatype of every field
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %% [markdown]
# # convert to numpy array

# %%
finance.to_numpy()
# Out:
# array([[10, 'Level 1', '99999', ..., 'Financial performance', '733,258',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2020, 'Level 1', '99999', ..., 'Financial performance',
#         '660,630',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2020, 'Level 1', '99999', ..., 'Financial performance', '54,342',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        ...,
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '12',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '5',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
# ...

# %% [markdown]
# ## Transpose (convert row to column)

# %%
finance.T
# Out:
# Year                                                                      10    \
# Year                                                                        10
# Industry_aggregation_NZSIOC                                            Level 1
# Industry_code_NZSIOC                                                     99999
# Industry_name_NZSIOC                                            All industries
# Units                                                       Dollars (millions)
# Variable_code                                                              H01
# Variable_name                                                     Total income
# Variable_category                                        Financial performance
# Value                                                                  733,258
# Industry_code_ANZSIC06       ANZSIC06 divisions A-S (excluding classes K633...
#
# Year                                                                      2020  \
# ...

# %%
finance.sort_index(axis = 1 , ascending = False)   # defalut ascending is True
# Out:
#       Year                                    Variable_name Variable_code  \
# Year
# 10      10                                     Total income           H01
# 2020  2020  Sales, government funding, grants and subsidies           H04
# 2020  2020                Interest, dividends and donations           H05
# 2020  2020                             Non-operating income           H07
# 2020  2020                                Total expenditure           H08
# ...    ...                                              ...           ...
# 2013  2013                                      Quick ratio           H37
# 2013  2013              Margin on sales of goods for resale           H38
# 2013  2013                                 Return on equity           H39
# 2013  2013                           Return on total assets           H40
# 2013  2013                            Liabilities structure           H41
#
#           Variable_category    Value               Units  \
# Year
# ...

# %%
finance.drop("Value" , axis = 1)
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 10      10                     Level 1                99999
# 2020  2020                     Level 1                99999
# 2020  2020                     Level 1                99999
# 2020  2020                     Level 1                99999
# 2020  2020                     Level 1                99999
# ...    ...                         ...                  ...
# 2013  2013                     Level 3                 ZZ11
# 2013  2013                     Level 3                 ZZ11
# 2013  2013                     Level 3                 ZZ11
# 2013  2013                     Level 3                 ZZ11
# 2013  2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 10                All industries  Dollars (millions)           H01
# 2020              All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# ## use of loc ad iloc

# %%
finance.loc[0,0] = 43 # for loc we have to type the proper name of column or the index

# %%
finance
# Out:
#         Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 10      10.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# ...      ...                         ...                  ...
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 0        NaN                         NaN                  NaN
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 10                All industries  Dollars (millions)           H01
# 2020              All industries  Dollars (millions)           H04
# ...

# %%
finance.drop(0 , axis = 1)
# Out:
#         Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 10      10.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# 2020  2020.0                     Level 1                99999
# ...      ...                         ...                  ...
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 0        NaN                         NaN                  NaN
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 10                All industries  Dollars (millions)           H01
# 2020              All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# ## to get some row or some column

# %%
finance.loc[[10,2013] , ["Industry_aggregation_NZSIOC" , "Industry_name_NZSIOC"]]
# Out:
#      Industry_aggregation_NZSIOC        Industry_name_NZSIOC
# Year
# 10                       Level 1              All industries
# 2013                     Level 1              All industries
# 2013                     Level 1              All industries
# 2013                     Level 1              All industries
# 2013                     Level 1              All industries
# ...                          ...                         ...
# 2013                     Level 3  Food product manufacturing
# 2013                     Level 3  Food product manufacturing
# 2013                     Level 3  Food product manufacturing
# 2013                     Level 3  Food product manufacturing
# 2013                     Level 3  Food product manufacturing
#
# [4636 rows x 2 columns]

# %% [markdown]
# ## select all column

# %%
finance.loc[[10] , "Units":]  # a:b a means start from there and b means end here if no a or b so select all.
# Out:
#                    Units Variable_code Variable_name      Variable_category  \
# Year
# 10    Dollars (millions)           H01  Total income  Financial performance
#
#         Value                             Industry_code_ANZSIC06   0
# Year
# 10    733,258  ANZSIC06 divisions A-S (excluding classes K633... NaN

# %% [markdown]
# ## we can use the complex statements using loc

# %%
finance.loc[(finance["Year"] < 2015)]
# Out:
#         Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 10      10.0                     Level 1                99999
# 2014  2014.0                     Level 1                99999
# 2014  2014.0                     Level 1                99999
# 2014  2014.0                     Level 1                99999
# 2014  2014.0                     Level 1                99999
# ...      ...                         ...                  ...
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
# 2013  2013.0                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 10                All industries  Dollars (millions)           H01
# 2014              All industries  Dollars (millions)           H01
# ...

# %% [markdown]
# ## we can use the number as well not mandatory to use name of coumn by usering iloc

# %%
finance.iloc[0,0]
# Out:
# 10.0

# %% [markdown]
# # inplace set the changes as permanent

# %%
finance.drop("Industry_aggregation_NZSIOC" , axis = 1, inplace = True)

# %%
finance
# Out:
#         Year Industry_code_NZSIOC        Industry_name_NZSIOC  \
# Year
# 10      10.0                99999              All industries
# 2020  2020.0                99999              All industries
# 2020  2020.0                99999              All industries
# 2020  2020.0                99999              All industries
# 2020  2020.0                99999              All industries
# ...      ...                  ...                         ...
# 2013  2013.0                 ZZ11  Food product manufacturing
# 2013  2013.0                 ZZ11  Food product manufacturing
# 2013  2013.0                 ZZ11  Food product manufacturing
# 2013  2013.0                 ZZ11  Food product manufacturing
# 0        NaN                  NaN                         NaN
#
#                    Units Variable_code  \
# Year
# 10    Dollars (millions)           H01
# 2020  Dollars (millions)           H04
# 2020  Dollars (millions)           H05
# 2020  Dollars (millions)           H07
# ...

# %% [markdown]
# ## to reset index

# %%
finance.reset_index(drop = True , inplace = True)

# %%
finance
# Out:
#          Year Industry_code_NZSIOC        Industry_name_NZSIOC  \
# 0        10.0                99999              All industries
# 1      2020.0                99999              All industries
# 2      2020.0                99999              All industries
# 3      2020.0                99999              All industries
# 4      2020.0                99999              All industries
# ...       ...                  ...                         ...
# 37076  2013.0                 ZZ11  Food product manufacturing
# 37077  2013.0                 ZZ11  Food product manufacturing
# 37078  2013.0                 ZZ11  Food product manufacturing
# 37079  2013.0                 ZZ11  Food product manufacturing
# 37080     NaN                  NaN                         NaN
#
#                     Units Variable_code  \
# 0      Dollars (millions)           H01
# 1      Dollars (millions)           H04
# 2      Dollars (millions)           H05
# 3      Dollars (millions)           H07
# ...

# %%
finance.loc[:,"Industry_code_NZSIOC"] = None  #setting all value of perticular column as none

# %%
finance.head()
# Out:
#      Year Industry_code_NZSIOC Industry_name_NZSIOC               Units  \
# 0    10.0                 None       All industries  Dollars (millions)
# 1  2020.0                 None       All industries  Dollars (millions)
# 2  2020.0                 None       All industries  Dollars (millions)
# 3  2020.0                 None       All industries  Dollars (millions)
# 4  2020.0                 None       All industries  Dollars (millions)
#
#   Variable_code                                    Variable_name  \
# 0           H01                                     Total income
# 1           H04  Sales, government funding, grants and subsidies
# 2           H05                Interest, dividends and donations
# 3           H07                             Non-operating income
# 4           H08                                Total expenditure
#
#        Variable_category    Value  \
# 0  Financial performance  733,258
# 1  Financial performance  660,630
# ...

# %%
#checking value is none or not  (always use loc)
finance.loc[:,"Industry_code_NZSIOC"].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 37076    True
# 37077    True
# 37078    True
# 37079    True
# 37080    True
# Name: Industry_code_NZSIOC, Length: 37081, dtype: bool

# %% [markdown]
# ## remove null value

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
# syntax :   DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#subset tell which value should he check

df.dropna(subset=["name", "born"] , axis= 0)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
